# %% [markdown]
# # Final Project: Breast Cancer Prediction Model using SVM

# %% [markdown]
# ### Candidate Name: Mayur Kumar Sharma
# ### Batch: DW-32

# %%
# Using the given dataset, I've created a model which is useful for breast cancer prediction.

# %% [markdown]
# ### Importing the required libraries & packages

# %%
import pandas as pd
import numpy as np
import sklearn.datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn import svm
from sklearn.metrics import classification_report

# %%
# Reading the dataset & creating a dataframe

df = pd.read_csv('cancer.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# By using describe() method we get useful information about the dataset as shown above.

# %%
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
df['diagnosis']
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %% [markdown]
# By checking the data-types of columns, we can find the type of data present in the respective feature.
# Here 'diagnosis' has object data-type, on which we can not perform mathematical operations.
# So we'll encode it using Label-Encoder technique.
# (It has two classes 'M' & 'B')
# Then we'll drop this feature & add new feature 'result', obtained from label-encoder, into our dataframe.

# %%
le = LabelEncoder()
df['result'] = le.fit_transform(df['diagnosis'])
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# ### By checking the Null values count, we need to drop 'Unnamed: 32' also along with 'id', as both of them are not required for our model.

# %%
df.drop(['Unnamed: 32'], axis=1, inplace=True)

# %%
df.drop(['diagnosis'], axis=1, inplace=True)

# %%
df.drop(['id'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (569, 31)

# %% [markdown]
# Finally, after applying data cleaning & preprocessing, we got a dataset with rows=569 & columns=31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   radius_mean              569 non-null    float64
#  1   texture_mean             569 non-null    float64
#  2   perimeter_mean           569 non-null    float64
#  3   area_mean                569 non-null    float64
#  4   smoothness_mean          569 non-null    float64
#  5   compactness_mean         569 non-null    float64
#  6   concavity_mean           569 non-null    float64
#  7   concave points_mean      569 non-null    float64
#  8   symmetry_mean            569 non-null    float64
#  9   fractal_dimension_mean   569 non-null    float64
#  10  radius_se                569 non-null    float64
#  11  texture_se               569 non-null    float64
#  12  perimeter_se             569 non-null    float64
# ...

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# By this describe() method, we get to know useful statistics about our features separately.

# %%
df['result'].value_counts()  #357=Benign=0, 212=Malignant=1
# Out:
# 0    357
# 1    212
# Name: result, dtype: int64

# %% [markdown]
# ## Class 0 = Benign = total 357 ___&___ Class 1 = Malignant = total 212

# %%
df.groupby('result').mean()
# Out:
#         radius_mean  texture_mean  perimeter_mean   area_mean  \
# result
# 0         12.146524     17.914762       78.075406  462.790196
# 1         17.462830     21.604906      115.365377  978.376415
#
#         smoothness_mean  compactness_mean  concavity_mean  \
# result
# 0              0.092478          0.080085        0.046058
# 1              0.102898          0.145188        0.160775
#
#         concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# result                                                              ...
# 0                  0.025717       0.174186                0.062867  ...
# 1                  0.087990       0.192909                0.062680  ...
#
#         radius_worst  texture_worst  perimeter_worst   area_worst  \
# result
# 0          13.379801      23.515070        87.005938   558.899440
# 1          21.134811      29.318208       141.370330  1422.286321
#
#         smoothness_worst  compactness_worst  concavity_worst  \
# result
# ...

# %% [markdown]
# ### After finding the number or counts of both the classes, we obtained average results for the features. Now we need to divide our data into input_to_model (x) & target (y).

# %%
x = df.drop(columns = 'result', axis=1)
y = df['result']

# %%
print(x)

# %%
print(y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: result, Length: 569, dtype: int32

# %% [markdown]
# ### To create a model we need to divide the data set into 4-main categories as shown below:

# %%
# We'll use 20% data for testing

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (569, 30) (455, 30) (114, 30) (455,) (114,)

# %% [markdown]
# # Model Training : Support Vector Machine

# %% [markdown]
# We will create our Support Vector Machine model using scikit-learn.
# SVM is used as classification techniques which first attempts to find Hyperplane, which can separate objects of different classes and then leaves maximum marigin from the nearest points of each class to the separating hyperplane.

# %%
model = svm.SVC(kernel = 'linear', gamma = 'auto', C=0.3)

# %% [markdown]
# Here kernel, gamma & c are explained below:
# 1. kernel method is a class of algorithms for pattern analysis.
# 2. gamma parameter determines the distance a single data sample exerts influence or it is said to adjust the curvature of the decision boundary.
# 3. C determines penalty or how many samples are allowed to be placed in different classes.

# %%
model.fit(x_train, y_train)
# Out:
# SVC(C=0.3, gamma='auto', kernel='linear')

# %%
y_predicted = model.predict(x_test)

# %% [markdown]
# By doing this we can find the difference between the actual data (y_test) & predicted data (y_predicted.
#
# Further, we will evaluate the results & check the precision and f1 score.

# %% [markdown]
# ## Results, Precision and F1 score

# %%
print(classification_report(y_test, y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        69
#            1       0.93      0.91      0.92        45
#
#     accuracy                           0.94       114
#    macro avg       0.94      0.93      0.94       114
# weighted avg       0.94      0.94      0.94       114

# %% [markdown]
# Here,
# 1. Precision: Precision measures the percentage of true positives (correctly predicted positive instances) out of all predicted positives. It gives an indication of how accurate the model's positive predictions are.
#
#     Precision = True Positives / (True Positives + False Positives)
#
#
# 2. Recall: Recall measures the percentage of true positives out of all actual positives. It gives an indication of how well the model is able to identify positive instances.
#
#     Recall = True Positives / (True Positives + False Negatives)
#
#
# 3. F1-score: The F1-score is the harmonic mean of precision and recall, and is a balanced metric that takes both into account. It provides a single measure of a model's performance.
#
#     F1-score = 2 * (Precision * Recall) / (Precision + Recall)
#
#
# 4. support means instances.

# %% [markdown]
# ### Class 0 = Benign
# ### Class 1 = Malignant

# %% [markdown]
# # Here 114 is number of Test-Data.
# # Prediction by model is 69 (Benign) + 45(Malignant).
# # This is the result of our dataset with accuracy of 94%.

# %% [markdown]
# # -
# # -
# # -
# # -
# ### Thank You
# ### Prepared By: Mayur Kumar Sharma / DW-32 Batch / GUVI
